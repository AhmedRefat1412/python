# %%
import pymongo

# %%
#هنا بنعرفه ان السيرفر لوكل 
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mydb
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase')

# %%
# بيرجع كل اسماء الداتا بيز 
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'local', 'mydatabase', 'mydb', 'school']

# %%
mycol = mydb["customers"]
mycol
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase'), 'customers')

# %%
#Insert a record in the "customers" collection:
#insert_one
import pymongo
myclient=pymongo.MongoClient("mongodb://localhost:27017/")
mydb=myclient["mydatabase"]
mycol=mydb["customers"]

newdouc={"name":"ahmed","adress":"baltim"}
x=mycol.insert_one(newdouc)

mycol.find_one({"name":"ahmed"})
# Out:
# {'_id': ObjectId('68bcb09c1d378012d3c219e5'),
#  'name': 'ahmed',
#  'adress': 'baltim'}

# %%
# insert many
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

mylist = [
  { "name": "Amy", "address": "Apple st 652"},
  { "name": "Hannah", "address": "Mountain 21"},
  { "name": "Michael", "address": "Valley 345"},
  { "name": "Sandy", "address": "Ocean blvd 2"},
  { "name": "Betty", "address": "Green Grass 1"},
  { "name": "Richard", "address": "Sky st 331"},
  { "name": "Susan", "address": "One way 98"},
  { "name": "Vicky", "address": "Yellow Garden 2"},
  { "name": "Ben", "address": "Park Lane 38"},
  { "name": "William", "address": "Central st 954"},
  { "name": "Chuck", "address": "Main Road 989"},
  { "name": "Viola", "address": "Sideway 1633"}
]

x = mycol.insert_many(mylist)

      # find to all documents in collection
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('68bcb09c1d378012d3c219e5'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb0a71d378012d3c219e7'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1451d378012d3c219e9'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1481d378012d3c219eb'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1501d378012d3c219ee'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1551d378012d3c219f0'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1581d378012d3c219f3'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb8bb1d378012d3c219f5'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb9131d378012d3c219f7'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb99d1d378012d3c219f9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcb99d1d378012d3c219fa'), 'name': 'Hannah', 'address': 'Mountain 21'}
# ...

# %%
      #عشان اعرض العنوان بس لكل الداتا 

for x in mycol.find({},{ "address": 1 ,"_id":0}):
  print(x)
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'address': 'Apple st 652'}
# {'address': 'Mountain 21'}
# {'address': 'Valley 345'}
# {'address': 'Ocean blvd 2'}
# {'address': 'Green Grass 1'}
# {'address': 'Sky st 331'}
# {'address': 'One way 98'}
# {'address': 'Yellow Garden 2'}
# {'address': 'Park Lane 38'}
# {'address': 'Central st 954'}
# {'address': 'Main Road 989'}
# {'address': 'Sideway 1633'}
# {'address': 'Apple st 652'}
# {'address': 'Mountain 21'}
# {'address': 'Valley 345'}
# {'address': 'Ocean blvd 2'}
# {'address': 'Green Grass 1'}
# {'address': 'Sky st 331'}
# {'address': 'One way 98'}
# {'address': 'Yellow Garden 2'}
# {'address': 'Park Lane 38'}
# {'address': 'Central st 954'}
# {'address': 'Main Road 989'}
# {'address': 'Sideway 1633'}
# {'address': 'Apple st 652'}
# {'address': 'Mountain 21'}
# {'address': 'Valley 345'}
# {'address': 'Ocean blvd 2'}
# {'address': 'Green Grass 1'}
# {'address': 'Sky st 331'}
# {'address': 'One way 98'}
# ...

# %%
#To find only the documents where the "address" field starts with the letter "S", use the regular expression {"$regex": "^S"}:


import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

myquery = { "address": { "$regex": "^S" } }

mydoc = mycol.find(myquery)

for x in mydoc:
  print(x)
# Out:
# {'_id': ObjectId('68bcb99d1d378012d3c219fe'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('68bcb99d1d378012d3c21a04'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('68bcb9ba1d378012d3c21a0b'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('68bcb9ba1d378012d3c21a11'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('68bcb9c51d378012d3c21a18'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('68bcb9c51d378012d3c21a1e'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('68bcb9ce1d378012d3c21a25'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('68bcb9ce1d378012d3c21a2b'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('68bcb9d81d378012d3c21a32'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('68bcb9d81d378012d3c21a38'), 'name': 'Viola', 'address': 'Sideway 1633'}
# ...

# %%
#Sort the result alphabetically by name:

# sort("name", 1) #ascending
# sort("name", -1) #descending

import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

mydoc = mycol.find().sort("name")

for x in mydoc:
  print(x)
# Out:
# {'_id': ObjectId('68bcba271d378012d3c21a3a'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcb9d81d378012d3c21a2d'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcb99d1d378012d3c219f9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcbaa21d378012d3c21a54'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcba411d378012d3c21a47'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcb9c51d378012d3c21a13'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcb9ce1d378012d3c21a20'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcb9ba1d378012d3c21a06'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcba271d378012d3c21a42'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('68bcb9d81d378012d3c21a35'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('68bcbaa21d378012d3c21a5c'), 'name': 'Ben', 'address': 'Park Lane 38'}
# ...

# %%
#Delete the document with the address "Mountain 21":

import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

myquery = { "address": "Mountain 21" }

mycol.delete_one(myquery)

# %%
# delete many doucments
#Delete all documents were the address starts with the letter S:

import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

myquery = { "address": {"$regex": "^S"} }

x = mycol.delete_many(myquery)

print(x.deleted_count, " documents deleted.")

# %% [markdown]
# update
# ----------

# %%
# update one
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

myquery = { "address": "Valley 345" }
newvalues = { "$set": { "address": "Canyon 123" } }

mycol.update_one(myquery, newvalues)

#print "customers" after the update:
for x in mycol.find():
  print(x)

# %%
# update many
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

myquery = { "address": "Valley 345" }
newvalues = { "$set": { "address": "Canyon 123" } }

mycol.update_many(myquery, newvalues)

#print "customers" after the update:
for x in mycol.find():
  print(x)
# Out:
# {'_id': ObjectId('68bcb09c1d378012d3c219e5'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb0a71d378012d3c219e7'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1451d378012d3c219e9'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1481d378012d3c219eb'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1501d378012d3c219ee'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1551d378012d3c219f0'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1581d378012d3c219f3'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb8bb1d378012d3c219f5'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb9131d378012d3c219f7'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb99d1d378012d3c219f9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('68bcb99d1d378012d3c219fa'), 'name': 'Hannah', 'address': 'Mountain 21'}
# ...

# %% [markdown]
# limit
# -----------

# %%
#Limit the result to only return 5 documents:

import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

myresult = mycol.find().limit(5)

#print the result:
for x in myresult:
  print(x)
# Out:
# {'_id': ObjectId('68bcb09c1d378012d3c219e5'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb0a71d378012d3c219e7'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1451d378012d3c219e9'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1481d378012d3c219eb'), 'name': 'ahmed', 'adress': 'baltim'}
# {'_id': ObjectId('68bcb1501d378012d3c219ee'), 'name': 'ahmed', 'adress': 'baltim'}
